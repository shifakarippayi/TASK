# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import numpy as np

# %%
imag= cv2.imread('cofee.jpg')

# %%
imag.shape
# Out:
# (6240, 4160, 3)

# %%
imag
# Out:
# array([[[187, 184, 179],
#         [187, 184, 179],
#         [187, 184, 179],
#         ...,
#         [ 42,  43,  47],
#         [ 46,  47,  51],
#         [ 37,  38,  42]],
#
#        [[186, 183, 178],
#         [186, 183, 178],
#         [186, 183, 178],
#         ...,
#         [ 52,  53,  57],
#         [ 45,  46,  50],
#         [ 50,  51,  55]],
#
#        [[184, 181, 176],
#         [185, 182, 177],
#         [186, 183, 178],
#         ...,
#         [ 55,  53,  59],
#         [ 47,  45,  51],
#         [ 53,  51,  57]],
#
#        ...,
#
#        [[ 22,  30,  20],
#         [ 18,  26,  16],
#         [ 17,  25,  14],
#         ...,
#         [ 21,  37,  26],
#         [ 18,  34,  23],
#         [ 19,  35,  24]],
#
#        [[ 21,  29,  18],
#         [ 20,  28,  17],
#         [ 21,  29,  18],
#         ...,
#         [ 21,  37,  26],
#         [ 21,  37,  26],
#         [ 24,  40,  29]],
#
#        [[ 15,  23,  12],
#         [ 19,  27,  16],
#         [ 23,  31,  20],
# ...

# %%
h,w= imag.shape[:2]

# %%
h
# Out:
# 6240

# %%
w
# Out:
# 4160

# %%
image= cv2.imread('cofee.jpg')
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image= cv2.imread('cofee.jpg')
cv2.imshow('COFEE',image)
cv2.waitKey(0)             
cv2.destroyAllWindows()

# %%
img= cv2.resize(image,(350,550))

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
